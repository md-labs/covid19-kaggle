# %% [markdown]
# <a href="https://colab.research.google.com/github/md-labs/covid19-kaggle/blob/hong/ensemble/ensemble.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
from collections import defaultdict, Counter
import numpy as np
import pandas as pd
from pathlib import Path
from random import choice

random.seed(2020)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class VoteEnsemble:
  def __init__(self):
    self.root_dir = Path('/content/drive/Shared drives/COVID-19-Research/')
    self.jsons = []
    self.majority_vote = None

  def _load_json(self):
    if self.jsons:
      return

    with open(self.root_dir / 'results/Hong/votes.json') as f:
      self.jsons.append([json.load(f)])
    with open(self.root_dir / 'results/Mihir/ensemble_results.json') as f:
      self.jsons.append([json.load(f)])
    with open(self.root_dir / 'results/Jitesh/elasticbert_labels.json') as f1:
      with open(self.root_dir / 'results/Jitesh/google_labels.json') as f2:
        self.jsons.append([json.load(f1), json.load(f2)])
    with open(self.root_dir / 'results/Rishab/bert_1.json') as f1:
      with open(self.root_dir / 'results/Rishab/biobert_1.json') as f2:
        with open(self.root_dir / 'results/Rishab/fine_tuned_1.json') as f3:
          self.jsons.append([json.load(f1), json.load(f2), json.load(f3)])
    # load Ashwin's results
    label_map = {'O':0, 'VC':1, 'TR':2}
    with open(self.root_dir / 'results/Ashwin/JSON_Files_For_Ensemble/labels/COVID_Labels_After_Classification_CH_labels.json') as f1:
      json1 = json.load(f1)
      json1 = {key: label_map[value] for key, value in json1.items()}
      with open(self.root_dir / 'results/Ashwin/JSON_Files_For_Ensemble/labels/Filter_After_FineTuning_labels.json') as f2:
        json2 = json.load(f2)
        json2 = {key: label_map[value] for key, value in json2.items()}
        with open(self.root_dir / 'results/Ashwin/JSON_Files_For_Ensemble/labels/Filter_Before_FineTuning_labels.json') as f3:
          json3 = json.load(f3)
          json3 = {key: label_map[value] for key, value in json3.items()}       
          self.jsons.append([json1, json2, json3]) 
  
  def _get_majority_vote(self, votes):
    """
    Args: 
      votes: a list of dictionary {'title': class}, where class is one of {0, 1, 2},
             0 for not related, 1 for vaccine related, 2 for therapeutics related
    Return:
      vote: a single dictionary {'title': class}
    """
    all_titles = set()
    for v in votes:
      all_titles |= set(v.keys())

    # combining votes
    vote = {title: Counter([v[title] for v in votes if title in v]) for title in all_titles}
    # pick highest vote:
    result = {}
    for title, counter in vote.items():
      freq = counter.most_common(1)[0][1]
      candidate_cls = [cls for cls, num_votes in counter.items() if num_votes == freq]
      result[title] = choice(candidate_cls)

    return result

  def _combine_individual_votes(self):
    if not self.jsons:
      self._load_json()

    for i, votes in enumerate(self.jsons):
      if len(votes) == 1:
        self.jsons[i] = votes[0]
      else:
        self.jsons[i] = self._get_majority_vote(votes)

  def majority_vote_ensemble(self):
    if self.majority_vote is not None:
      return self.majority_vote

    self._combine_individual_votes()
    self.majority_vote = self._get_majority_vote(self.jsons)
    return self.majority_vote

# %%
ensemble = VoteEnsemble()
print(Counter(ensemble.majority_vote_ensemble().values()))
# Out:
# Counter({0: 37342, 2: 7588, 1: 5455})

# %%
ensemble.majority_vote
# Out:
# {'Biosafety and Bioethics': 1,
#  'Combination of IMOD™ and Arbidol to increase their immunomodulatory effects as a novel medicine to prevent and cure influenza and some other infectious diseases': 0,
#  'The Control of Acute Undifferentiated Diarrhea of Newborn Beef Calves': 0,
#  'Medical Anthropology': 0,
#  'Epidemic Wave Dynamics Attributable to Urban Community Structure: A Theoretical Characterization of Disease Transmission in a Large Network': 1,
#  'Effect of Glycyrrhizin on Pseudomonal Skin Infections in Human-Mouse Chimeras': 2,
#  'Novel coronavirus infection and pregnancy': 0,
#  'Peptide domains involved in the localization of the porcine reproductive and respiratory syndrome virus nucleocapsid protein to the nucleolus': 2,
#  'Non-traditional outbreak surveillance - the 15 year experience': 0,
#  'Disease Transmission and Networks ☆': 0,
#  "Chapter 11 Safety and Security Issues Affecting Inbound Tourism in the People's Republic of China": 0,
#  'Structural disorder in the proteome and interactome of Alkhurma virus (ALKV)': 1,
#  'Comparison of incubation period distribution of human infections with MERS-CoV in South Korea and Saudi Arabia': 1,
#  'Chapter 6 Cubic Membranes The Missing Dimension of Cell Membrane Organization': 0,
#  'Coronavirus hält Weltkonjunktur in Atem': 0,
#  'Psycho-immunologie: un modèle en question': 0,
#  'Cumulative subject index volumes 156–161': 0,
#  'An efficient pattern growth approach for mining fault tolerant frequent itemsets': 2,
#  'Involvement of a subgenomic mRNA in the generation of a variable population of defective citrus tristeza virus molecules.': 0,
#  'Influence of plant origin on propagation capacity and alkaloid biosynthesis during long-term in vitro cultivation of Leucojum aestivum L.': 0,
#  'Precision Public Health for the Era of Precision Medicine': 0,
#  'Changes in the Transcriptome of Human Astrocytes Accompanying Oxidative Stress-Induced Senescence': 0,
#  'A non-linear model of information sharing practices in academic communities': 2,
#  'Infektiologie': 0,
#  'Rotavirus diarrhoea in patient with antibody to human immunodeficiency virus (HIV)': 0,
#  'Respiratory Virus Infections in People Over 14 Years of Age in Poland in the Epidemic Season of 2017/18': 0,
#  'Evaluation of 2 different treatment procedures after calving to improve harvesting of high-quantity and high-quality colostrum': 1,
#  'IL-27 Is Elevated in Patients With COPD and Patients With Pulmonary TB and Induces Human Bronchial Epithelial Cells to Produce CXCL10': 0,
#  'Pulmonary and Hepatic Complications of Hematopoietic Cell Transplantation': 0,
#  'Levels of complexity in pathogen recognition by C-type lectins': 2,
#  'Identification of G-quadruplex forming sequences in three manatee papillomaviruses': 1,
#  'A Genome-Wide Expression Analysis in Blood Identifies Pre-Elafin as a Biomarker in ARDS': 0,
#  'Reduction of tumor necrosis factor production by splenocytes from v-Ha-ras oncogene-bearing mice': 0,
#  'Diagnostic performance and clinical feasibility of a point-of-care test for respiratory viral infections in primary health care': 0,
#  'Plans and prospects for the 2020s: Beyond peak health?': 0,
#  'Mutations in the spike gene of porcine epidemic diarrhea virus associated with growth adaptation in vitro and attenuation of virulence in vivo': 0,
#  'Associations between genetics, farm characteristics and clinical disease in field outbreaks of porcine reproductive and respiratory syndrome virus': 0,
#  'Surface Plasmon Resonance: A Boon for Viral Diagnostics': 0,
#  'Alteration of intracellular traffic by monensin; mechanism, specificity and relationship to toxicity': 0,
#  'Inhibition of Henipavirus infection by RNA interference': 2,
#  'The Acute Chest Syndrome in Cameroonian children living with sickle cell disease': 0,
#  'The Role of Phosphodiesterase 12 (PDE12) as a Negative Regulator of the Innate Immune Response and the Discovery of Antiviral Inhibitors': 0,
#  'Métodos moleculares de diagnóstico de infecciones respiratorias. ¿Ha cambiado el esquema diagnóstico?': 0,
#  'The fecal virome of domesticated animals': 0,
#  'Newcastle disease virus-based MERS-CoV candidate vaccine elicits high-level and lasting neutralizing antibodies in Bactrian camels': 0,
#  'SARS, the First Pandemic of the 21st Century': 0,
#  'Radiological Findings in Severe Acute Respiratory Syndrome': 0,
#  'Microbicides and the environmental control of nosocomial viral infections()': 2,
#  'Effect of a quadrivalent vaccine against respiratory virus on the incidence of respiratory disease in weaned beef calves': 0,
#  'Hijacking DNA methyltransferase transition state analogues to produce chemical scaffolds for PRMT inhibitors': 0,
#  'Clinical Application of a Multiplex Real-Time PCR Assay for Simultaneous Detection of Legionella Species, Legionella pneumophila, and Legionella pneumophila Serogroup 1': 0,
#  'Structure of the C-terminal domain of nsp4 from feline coronavirus': 2,
#  'Long non-coding RNA Gm15441 attenuates hepatic inflammasome activation in response to metabolic stress': 2,
#  "Development of reagents to study the turkey's immune response: Cloning and characterisation of two turkey cytokines, interleukin (IL)-10 and IL-13": 0,
#  'The Edinburgh microbiology archive': 0,
#  'Infrastructure and Contamination of the Physical Environment in Three Bangladeshi Hospitals: Putting Infection Control into Context': 1,
#  'Dynamic graphs, community detection, and Riemannian geometry': 0,
#  'Turning Up Your Nose for a Flaviviral Encephalitis Cure': 0,
#  'RT-PCR Detection of Avian Coronaviruses of Galliform Birds (Chicken, Turkey, Pheasant) and in a Parrot': 2,
#  'The clinical value of biomarkers in respiratory complications in hematopoietic SCT': 0,
#  'A 1-Year Experience with Human Metapneumovirus in Children Aged <5 Years': 0,
#  "Gatekeepers of health: A qualitative assessment of child care centre staff's perspectives, practices and challenges to enteric illness prevention and management in child care centres": 0,
#  'A mathematical model for the spatiotemporal epidemic spreading of COVID19': 2,
#  'Evaluation of SSYA10-001 as a Replication Inhibitor of Severe Acute Respiratory Syndrome, Mouse Hepatitis, and Middle East Respiratory Syndrome Coronaviruses': 0,
#  'Health protection guideline of public transport during the novel coronavirus pneumonia(NCP) outbreak': 0,
#  'Insights From Analysis of Human Antigen-Specific Memory B Cell Repertoires': 1,
#  'An Impaired Breeding Phenotype in Mice with a Genetic Deletion of Beta-2 Microglobulin and Diminished MHC Class I Expression: Role in Reproductive Fitness(1)': 0,
#  'The SARS-Coronavirus-Host Interactome: Identification of Cyclophilins as Target for Pan-Coronavirus Inhibitors': 0,
#  'Cumulative Author Index for 2005': 0,
#  'Design of synthetic peptides for oral vaccination': 0,
#  'Antibody-Validated Proteins in Inflamed Islets of Fulminant Type 1 Diabetes Profiled by Laser-Capture Microdissection Followed by Mass Spectrometry': 2,
#  'Association for Molecular Pathology 2006 Annual Meeting Abstracts': 0,
#  'Rapid pre-clinical detection of classical swine fever by reverse transcription loop-mediated isothermal amplification': 1,
#  'Deep learning Enables Accurate Diagnosis of Novel Coronavirus (COVID-19) with CT images': 0,
#  'Attachment and entry of recombinant Norwalk virus capsids to cultured human and animal cell lines.': 0,
#  'MERS coronavirus induces apoptosis in kidney and lung by upregulating Smad7 and FGF2': 0,
#  'Qualitative and Quantitative Analysis of 24 Components in Jinlianhua Decoction by UPLC–MS/MS': 0,
#  'Incidence, Etiology, and Outcomes of Community-Acquired Pneumonia: A Population-Based Study': 0,
#  'Fresh approaches to vaccine development: New financial and economic models are required to bring more vaccines against a wider range of diseases to the market': 0,
#  'Feline Coronavirus Type II Strains 79-1683 and 79-1146 Originate from a Double Recombination between Feline Coronavirus Type I and Canine Coronavirus': 1,
#  'Virome Profiling of Bats from Myanmar by Metagenomic Analysis of Tissue Samples Reveals More Novel Mammalian Viruses': 0,
#  'PERSISTENT CORONAVIRUS INFECTION OF PROGENITOR OLIGODENDROCYTES': 0,
#  'Aircraft engine exhaust emissions and other airport-related contributions to ambient air pollution: A review': 0,
#  'Physiological Level Production of Antigen-Specific Human Immunoglobulin in Cloned Transchromosomic Cattle': 0,
#  'Rat alveolar type I cells proliferate, express OCT-4, and exhibit phenotypic plasticity in vitro': 0,
#  'LABORATORIO DE VIROLOGÍA EN LA PRÁCTICA CLÍNICA': 0,
#  'What has Changed in Community-Acquired Pneumonia in Recent Years?': 0,
#  "Bromovirus RNA Replication Compartment Formation Requires Concerted Action of 1a's Self-Interacting RNA Capping and Helicase Domains": 2,
#  'A case report of the enterovirus-D68 associated severe acute respiratory illness in a pediatric case from India': 0,
#  'The year in review': 0,
#  'Translational research in immunology: Japanese perspectives': 0,
#  'Genotype and phenotype of COVID-19: Their roles in pathogenesis': 0,
#  'Sequence analysis reveals extensive polymorphism and evidence of deletions within the E2 glycoprotein gene of several strains of murine hepatitis virus': 1,
#  'Jacques-Louis David (1748–1825). Coronation of Empress Josephine by Napoleon I at Notre Dame de Paris, 2 December 1804 (1806–1807)': 0,
#  'Pharyngitis': 0,
#  'Index': 0,
#  'Immunological aspects of the efficiency of protectotype vaccination strategy against chicken infectious bronchitis': 1,
#  'The Group-Specific Murine Coronavirus Genes Are Not Essential, but Their Deletion, by Reverse Genetics, Is Attenuating in the Natural Host': 0,
#  'Diagnostic Virology Using Electron Microscopic Techniques': 0,
#  'Syndrome respiratoire aigu sévère ou SRAS': 0,
#  'Influence of Mabs on PrP(Sc) Formation Using In Vitro and Cell-Free Systems': 0,
#  'Comparison of bovine coronavirus (BCV) antigens: Monoclonal antibodies to the spike glycoprotein distinguish between vaccine and wild-type strains': 0,
#  'Image and structure quantitative analysis': 0,
#  "Realising equity in maternal health: China's successes and challenges": 0,
#  'Detection of foot-and-mouth disease virus infection-associated antigen antibodies: comparison of the enzyme-linked immunosorbent assay and agar gel immunodiffusion tests': 1,
#  'Clinical features of probable severe acute respiratory syndrome in Beijing': 0,
#  'Pyogranulomatous Pleuropneumonia and Mediastinitis in Ferrets Associated with Chryseomonas-like Bacteria': 0,
#  "Fit for the future? The place of global health in the UK's postgraduate medical training: a review": 0,
#  "In Case You Haven't Heard…": 0,
#  'Relationships between cold-temperature indices and all causes and cardiopulmonary morbidity and mortality in a subtropical island': 0,
#  'Infection of human oligodendroglioma cells by a recombinant measles virus expressing enhanced green fluorescent protein': 0,
#  'Positive Selection of the Bat Interferon Alpha Gene Family': 0,
#  'COVID‐19 Presents High Risk to Older Persons': 0,
#  'Human Coronavirus NL63 Infection is Associated with Croup': 0,
#  'Bird feathers as potential sources of pathogenic microorganisms: a new look at old diseases': 0,
#  'Public Health in Big Cities: Looking Back, Looking Forward': 0,
#  'Analytical Performance of a Loop-Mediated Isothermal Amplification Assay for Leishmania DNA Detection in Sandflies and Direct Smears of Patients with Cutaneous Leishmaniasis': 1,
#  'MHV-A59 Orf1a Replicase Protein NSP7-NSP10 Processing in Replication': 2,
#  'Endoplasmic reticulum stress-induced apoptosis in the development of reproduction': 2,
#  'CHAPTER 1 HISTORY OF VIRAL IMMUNOLOGY': 0,
#  'The host’s angiotensin-converting enzyme polymorphism may explain epidemiological findings in COVID-19 infections': 0,
#  'Impact of 2009 pandemic influenza among Vietnamese children based on a population-based prospective surveillance from 2007 to 2011': 0,
#  'Index to volume 4': 0,
#  'Killed in action: Microbiologists and clinicians as victims of their occupation Part 4: Tick-borne Relapsing Fever, Malta Fever, Glanders, SARS': 0,
#  'Rapid clinical diagnosis in fatal swine influenza (H1N1) pneumonia in an adult with negative rapid influenza diagnostic tests (RIDTs): Diagnostic swine influenza triad': 0,
#  "Can the concept of Health Promoting Schools help to improve students' health knowledge and practices to combat the challenge of communicable diseases: Case study in Hong Kong?": 0,
#  'A metagenomic comparison of endemic viruses from broiler chickens with runting-stunting syndrome and from normal birds': 0,
#  'The impact of the intracerebral antibody response on the clinical course of a virus-induced demyelination in a rat model system.': 0,
#  'Chapter 18 Use of artificial intelligence in infectious diseases': 0,
#  'Chapter 186 Angiotensin II Peptides': 0,
#  'In Vitro Resistance Selection and In Vivo Efficacy of Morpholino Oligomers against West Nile Virus': 0,
#  'The laboratory risk assessment and control testing 2019 novel coronavirus in biosafety class II laboratories': 0,
#  'Postexposure management of healthcare personnel to infectious diseases': 0,
#  'Mycoplasma felis-associated meningoencephalomyelitis in a cat': 0,
#  'A Sweet Spot for Molecular Diagnostics: Coupling Isothermal Amplification and Strand Exchange Circuits to Glucometers': 0,
#  'H1N1 infection and acute respiratory failure: can we give non-invasive ventilation a chance?': 0,
#  'The MAP3K7-mTOR Axis Promotes the Proliferation and Malignancy of Hepatocellular Carcinoma Cells': 2,
#  'Crystal structure of the SARS-CoV-2 non-structural protein 9, Nsp9': 2,
#  'Morphological changes in the jejunum of calves naturally infected with Giardia spp. and Cryptosporidium spp.': 0,
#  'Sudden hyposmia as a prevalent symptom of COVID-19 infection.': 0,
#  'Promoting Health Near and Far': 0,
#  'The time-varying serial interval of the coronavirus disease (COVID-19) and its gender-specific difference: A data-driven analysis using public surveillance data in Hong Kong and Shenzhen, China from January 10 to February 15, 2020': 0,
#  'Historical, New, and Reemerging Links between Human and Animal Health': 0,
#  'Canine Distemper Virus Matrix Protein Influences Particle Infectivity, Particle Composition, and Envelope Distribution in Polarized Epithelial Cells and Modulates Virulence': 0,
#  'Capacity building in national influenza laboratories – use of laboratory assessments to drive progress': 0,
#  'A neuropathic pain syndrome associated with hantavirus infection': 0,
#  'Modification of SARS-CoV S1 gene render expression in Pichia pastoris': 0,
#  'Multiantibody Strategies for HIV': 2,
#  'The neurobiology of canine distemper virus infection': 2,
#  'Inhibition of alphavirus infection in cell culture and in mice with antisense morpholino oligomers': 2,
#  'Killing More than Pain: Etiology and Remedy for an Opioid Crisis': 0,
#  'Contact structure, mobility, environmental impact and behaviour: the importance of social forces to infectious disease dynamics and disease ecology': 0,
#  'A germ-free status does not protect from the lethal effects of acute lung damage caused by o,s,s,-trimethyl phosphorodithioate': 1,
#  'Virtual screening for finding natural inhibitor against cathepsin-L for SARS therapy': 0,
#  'Stem–loop structures can effectively substitute for an RNA pseudoknot in −1 ribosomal frameshifting': 0,
#  'Novel therapeutic vaccines [(HSP65 + IL-12)DNA-, granulysin- and Ksp37-vaccine] against tuberculosis and synergistic effects in the combination with chemotherapy': 0,
#  'Correction to: Detection and full genome characterization of two beta CoV viruses related to Middle East respiratory syndrome from bats in Italy': 0,
#  'M1 of Murine Gamma-Herpesvirus 68 Induces Endoplasmic Reticulum Chaperone Production': 0,
#  'Chapter 9 Antimicrobial Use and Ecotoxicological Risks from Pandemics and Epidemics': 0,
#  'Research and Development of New Vaccines Against Infectious Diseases': 0,
#  'Li Wenliang': 0,
#  'Cholesteryl Pullulan Encapsulated TNF-α Nanoparticles Are an Effective Mucosal Vaccine Adjuvant against Influenza Virus': 1,
#  'Virus-specific RNA and Antibody from Convalescent-phase SARS Patients Discharged from Hospital': 0,
#  'Is Multiple-Sequence Alignment Required for Accurate Inference of Phylogeny?': 0,
#  'Development of Recombinase Polymerase Amplification Assays for Detection of Orientia tsutsugamushi or Rickettsia typhi': 0,
#  'First detection and molecular identification of Borrelia species in Bactrian camel (Camelus bactrianus) from Northwest China': 2,
#  'Epidemiology of Severe Acute Respiratory Infection (SARI) Cases at a sentinel site in Egypt, 2013–15': 0,
#  'Tracheostomy in a patient with severe acute respiratory syndrome': 0,
#  'Treatment of a Woman With Glycyrrhiza glabra for Acute Sinusitis: A Case Report': 0,
#  'Morphogenesis of Coronavirus HCoV-NL63 in Cell Culture: A Transmission Electron Microscopic Study': 0,
#  'The Human Virome': 0,
#  'Estimating Influenza Vaccine Effectiveness With the Test-Negative Design Using Alternative Control Groups: A Systematic Review and Meta-Analysis': 1,
#  'Kapitel 17 Epidemiologische Methoden zur Gewinnung verlässlicher Daten': 0,
#  'Protein Kinase C subtype δ interacts with Venezuelan equine encephalitis virus capsid protein and regulates viral RNA binding through modulation of capsid phosphorylation': 0,
#  'Identification and characterization of a G protein-coupled receptor homolog encoded by murine cytomegalovirus.': 2,
#  'Encephalitogenicity of myelin basic protein exon-2 peptide in mice': 0,
#  'The 3′ end of Turnip crinkle virus contains a highly interactive structure including a translational enhancer that is disrupted by binding to the RNA-dependent RNA polymerase': 0,
#  'Type I Interferon Receptor Deficiency in Dendritic Cells Facilitates Systemic Murine Norovirus Persistence Despite Enhanced Adaptive Immunity': 0,
#  'The Effect of Large-Scale Anti-Contagion Policies on the Coronavirus (COVID-19) Pandemic': 2,
#  'Childhood SARS in Singapore': 0,
#  'Biological Agents and Bioterrorism': 0,
#  'A Reverse Genetics System for Cypovirus Based on a Bacmid Expressing T7 RNA Polymerase': 0,
#  'Small interfering RNAs targeting the rabies virus nucleoprotein gene': 0,
#  'Binding of Avian Coronavirus Spike Proteins to Host Factors Reflects Virus Tropism and Pathogenicity': 0,
#  "Behavioural interventions to promote workers' use of respiratory protective equipment": 1,
#  'Ethical Obligations of Physicians Participating in Public Health Quarantine and Isolation Measures': 0,
#  'Lipidome profiles of postnatal day 2 vaginal swabs reflect fat composition of gilt’s postnatal diet': 0,
#  'Emerging and Neglected Infectious Diseases: Insights, Advances, and Challenges': 0,
#  'Inferring the hosts of coronavirus using dual statistical models based on nucleotide composition': 1,
#  'Vaccine against varicella-zoster virus (causative agent of chicken pox) using a DNA segment encoding the protective immunogenic gB glycoproteins': 0,
#  'The consequences of fear': 0,
#  'The Innate Antiviral Response in Animals: An Evolutionary Perspective from Flagellates to Humans': 0,
#  'ProMED-mail: 22 years of digital surveillance of emerging infectious diseases': 0,
#  'Radiological and Clinical Characteristics of a Military Outbreak of Pandemic H1N1 2009 Influenza Virus Infection': 0,
#  'HIV Antigen Incorporation within Adenovirus Hexon Hypervariable 2 for a Novel HIV Vaccine Approach': 1,
#  'Treatment of severe acute respiratory syndrome': 2,
#  'Myasthenia gravis: Antigen presentation by thymoma epithelial cells': 0,
#  'Cryo-EM structure of the 2019-nCoV spike in the prefusion conformation': 0,
#  'Diagnostic performance of near-patient testing for influenza': 0,
#  'Interventions to Mitigate Emergency Department and Hospital Crowding During an Infectious Respiratory Disease Outbreak: Results from an Expert Panel': 0,
#  "Class II-restricted T cell responses in Theiler's murine encephalomyelitis virus (TMEV)-induced demyelinating disease III. Failure of neuroantigen-specific immune tolerance to affect the clinical course of demyelination": 0,
#  'Subject index for volume 112': 0,
#  'WHO clinical trials initiative to protect the public.': 0,
#  'Mouse adenovirus type 1 causes a fatal hemorrhagic encephalomyelitis in adult C57BL/6 but not BALB/c mice.': 0,
#  'Experimental infection of dogs with a feline endogenous retrovirus RD-114': 1,
#  'Mycotoxicosis produced in rats by cultural products of an isolate of aspergillus ochraceus': 0,
#  'Introduction to the Symposium on Antimicrobial Therapy': 0,
#  'Coronavirus JHM: Cell-Free Synthesis of Structural Protein p60': 1,
#  'Molecular Diagnosis of Respiratory Tract Infection in Acute Exacerbations of Chronic Obstructive Pulmonary Disease': 0,
#  'Chapter 20 Ophthalmology of Exotic Pets': 0,
#  'WU polyomavirus in children with acute lower respiratory tract infections, China': 1,
#  'Prediction of quaternary assembly of SARS coronavirus peplomer': 2,
#  'Preparation, Characterization and Application of Polysaccharide-Based Metallic Nanoparticles: A Review': 2,
#  'Potent neutralizing monoclonal antibodies against Ebola virus infection': 0,
#  'Epidemiological surveillance and comparative analysis of patients with influenza like illness and other respiratory viruses': 0,
#  'Oral immunization of mice with live Pneumocystis murina protects against Pneumocystis pneumonia': 0,
#  'The Replicase Gene of Avian Coronavirus Infectious Bronchitis Virus Is a Determinant of Pathogenicity': 0,
#  'Chapter 19 Current and New Approaches for Mucosal Vaccine Delivery': 1,
#  'Tmprss2 Is Essential for Influenza H1N1 Virus Pathogenesis in Mice': 2,
#  'Chapter 4 Alimentary disorders': 0,
#  'The antiviral activity of naturally occurring proteins and their peptide fragments after chemical modification': 2,
#  'Safety of antimicrobial de-escalation for culture-negative severe pneumonia': 2,
#  'Successful treatment for the first confirmed noval coronavirus-infected pneumonia in Guizhou Province': 0,
#  'Current knowledge about the antivirals remdesivir (GS-5734) and GS-441524 as therapeutic options for coronaviruses': 0,
#  'Peptides Corresponding to the Predicted Heptad Repeat 2 Domain of the Feline Coronavirus Spike Protein Are Potent Inhibitors of Viral Infection': 2,
#  'Virus isolation and serum antibody responses after infection of cats with transmissible gastroenteritis virus': 1,
#  '19 Xenogenic Adenoviral Vectors': 0,
#  'Learning from Ebola: Interprofessional practice in the Nebraska Biocontainment Unit': 0,
#  'Bugs and Drugs: Oncolytic Virotherapy in Combination with Chemotherapy': 2,
#  'Descriptive epidemiology and characteristics of confirmed cases of Middle East respiratory syndrome coronavirus infection in the Makkah Region of Saudi Arabia, March to June 2014': 1,
#  'Chapter 477 Otubains': 0,
#  'Therapy and Long-Term Prophylaxis of Vaccinia Virus Respiratory Infections in Mice with an Adenovirus-Vectored Interferon Alpha (mDEF201)': 0,
#  'Current research status of immunology in the genomic era': 1,
#  'Coronavirus Spike Proteins in Viral Entry and Pathogenesis': 0,
#  'Frequent Detection of Respiratory Viruses without Symptoms: Toward Defining Clinically Relevant Cutoff Values': 0,
#  'Viral Infections of the Lower Respiratory Tract: Old Viruses, New Viruses, and the Role of Diagnosis': 1,
#  'Identification of Human Junctional Adhesion Molecule 1 as a Functional Receptor for the Hom-1 Calicivirus on Human Cells': 0,
#  'Antiviral Protection by IFITM3 In Vivo': 1,
#  'Chapter 37 Infection in Renal Transplant Recipients': 0,
#  'Rapid Diagnosis by Electron Microscopy of Avian Coronavirus Infection': 0,
#  'How do we plan hematopoietic cell transplant and cellular therapy with the looming COVID-19 threat?': 0,
#  'Teicoplanin: an alternative drug for the treatment of coronavirus COVID-19?': 2,
#  'WHO LAUNCHES NEW GLOBAL INFLUENZA STRATEGY': 0,
#  'Amino acids 1 to 422 of the spike protein of SARS associated coronavirus are required for induction of cyclooxygenase-2': 1,
#  'Identification of a novel B-cell epitope in the spike protein of porcine epidemic diarrhea virus': 0,
#  'Treatment of Diarrhea of Neonatal Calves': 0,
#  'cis-Acting Sequences Required for Coronavirus Infectious Bronchitis Virus Defective-RNA Replication and Packaging': 0,
#  'Evaluation of potential herb-drug interactions between oseltamivir and commonly used anti-influenza Chinese medicinal herbs': 0,
#  'Special edition editorial celebrating 25 years of publication': 1,
#  'Implications of Human Microbiome Research for the Developing World': 0,
#  "Minus-strand RNA synthesis in the spinal cords of mice persistently infected with Theiler's virus.": 0,
#  "Antibiothérapie par voie générale en pratique courante dans les infections respiratoires basses de l'adulte et de l'enfant. Argumentaire": 0,
#  'tailfindr: Alignment-free poly(A) length measurement for Oxford Nanopore RNA and DNA sequencing': 0,
#  'A Comprehensive Analytical Framework for Risks, Disasters and Crises': 0,
#  'Identification of a Gamma Interferon-Activated Inhibitor of Translation-Like RNA Motif at the 3′ End of the Transmissible Gastroenteritis Coronavirus Genome Modulating Innate Immune Response': 0,
#  'Silencing the alarms: Innate immune antagonism by rotavirus NSP1 and VP3': 0,
#  'Validation of the Arabic Version of the Early Childhood Oral Health Impact Scale (ECOHIS)': 1,
#  'An analytical study of behavioral risks and illness among camel keeper and non-camel keeper at zoo parks in Thailand 2014': 0,
#  'Pathogenesis and Pathology of Bovine Pneumonia': 0,
#  '2 Application of Plastics in Medical Devices and Equipment': 0,
#  'Lectin-like Intestinal Defensin Inhibits 2019-nCoV Spike binding to ACE2': 2,
#  'Plasma enteroglucagon and neurotensin levels in gnotobiotic calves infected with enteropathogenic and non-enteropathogenic viruses': 0,
#  'Using Patient-Specific Induced Pluripotent Stem Cells and Wild-Type Mice to Develop a Gene Augmentation-Based Strategy to Treat CLN3-Associated Retinal Degeneration': 2,
#  'Assessment of Hospital Emergency Department Response to Potentially Infectious Diseases Using Unannounced Mystery Patient Drills—New York City, 2016': 0,
#  'Discovery of a rich gene pool of bat SARS-related coronaviruses provides new insights into the origin of SARS coronavirus': 0,
#  'Novel Identified HLA-A*0201-Restricted Hantaan Virus Glycoprotein Cytotoxic T-Cell Epitopes Could Effectively Induce Protective Responses in HLA-A2.1/K(b) Transgenic Mice May Associate with the Severity of Hemorrhagic Fever with Renal Syndrome': 2,
#  'Alveolar levels of immuno-inflammatory mediators in diffuse alveolar hemorrhage after allogeneic transplant': 0,
#  'A preliminary study on serological assay for severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) in 238 admitted hospital patients': 0,
#  'Introduction: Conceptualizing and Partitioning the Emergence Process of Zoonotic Viruses from Wildlife to Humans': 0,
#  'Respiratory Viruses in the Neonatal Intensive Care Unit': 0,
#  'Mendelian resistance to human norovirus infections': 0,
#  'COVID-19: Global Radiation Oncology’s Targeted Response for Pandemic Preparedness': 0,
#  'Antiviral Efficacy of Verdinexor In Vivo in Two Animal Models of Influenza A Virus Infection': 2,
#  'Effect of air travel on the spread of an avian influenza pandemic to the United States': 0,
#  'MicroR‐9‐5p suppresses EV71 replication through targeting NFκB of the RIG‐I‐mediated innate immune response': 2,
#  'Lessons from the Ebola Outbreak: Action Items for Emerging Infectious Disease Preparedness and Response': 0,
#  'A community study of clinical traits and risk factors for human metapneumovirus and respiratory syncytial virus infection during the first year of life': 0,
#  'Clinician Wellness During the COVID-19 Pandemic: Extraordinary Times and Unusual Challenges for the Allergist/Immunologist': 0,
#  'Loop-Mediated Isothermal Amplification (LAMP) for the Diagnosis of Zika Virus: A Review': 0,
#  'Nucleolar targeting: the hub of the matter': 0,
#  'Chapter 4 Diseases of the respiratory system': 0,
#  'Virus persistence and recurring demyelination produced by a temperature-sensitive mutant of MHV-4': 0,
#  'Asymptomatic Shedding of Respiratory Virus among an Ambulatory Population across Seasons': 1,
#  'Laboratory diagnosis of SARS.': 0,
#  'AT2 receptors: Functional relevance in cardiovascular disease': 0,
#  'Evolution of the Bovine TLR Gene Family and Member Associations with Mycobacterium avium Subspecies paratuberculosis Infection': 2,
#  'Antiviral activity of Isatidis Radix derived glucosinolate isomers and their breakdown products against influenza A in vitro/ovo and mechanism of action': 1,
#  'Organ-Specific Attenuation of Murine Hepatitis Virus Strain A59 by Replacement of Catalytic Residues in the Putative Viral Cyclic Phosphodiesterase ns2': 0,
#  'Old World camels in a modern world – a balancing act between conservation and genetic improvement': 0,
#  'RSV-encoded NS2 promotes epithelial cell shedding and distal airway obstruction': 1,
#  'Forty-Five Years of Marburg Virus Research': 0,
#  'Specific Secretion of Active Single-Chain Fv Antibodies into the Supernatants of Escherichia coli Cultures by Use of the Hemolysin System': 0,
#  'Editorial Board and Contents': 0,
#  'Disasters from 1948 to 2015 in Korea and Power-Law Distribution': 0,
#  'Effectiveness of Interventions to Reduce Contact Rates during a Simulated Influenza Pandemic': 0,
#  'Appropriate Models for the Management of Infectious Diseases': 0,
#  'Mortality Rates of Human Metapneumovirus and Respiratory Syncytial Virus Lower Respiratory Tract Infections in Hematopoietic Cell Transplantation Recipients': 0,
#  'Acute kidney injury at early stage as a negative prognostic indicator of patients with COVID-19: a hospital-based retrospective analysis': 2,
#  'Chapter 17 Canine Viral Respiratory Infections': 0,
#  'Serological relation between calf diarrhea coronavirus and hemagglutinating encephalomyelitis virus': 1,
#  'Scrutinizing the SARS-CoV-2 protein information for the designing an effective vaccine encompassing both the T-cell and B-cell epitopes': 1,
#  'Murine Hepatitis Virus Strain 1 as a Model for Severe Acute Respiratory Distress Syndrome (Sars)': 2,
#  'CHAPTER 31 Translating Innovation in Diagnostics: Challenges and Opportunities': 0,
#  'High viral loads despite absence of clinical and pathological findings in cats experimentally infected with feline coronavirus (FCoV) type I and in naturally FCoV-infected cats': 0,
#  'Complex positive selection pressures drive the evolution of HIV-1 with different co-receptor tropisms': 2,
#  'Immunobiology of Long Noncoding RNAs': 0,
#  'Update on therapeutic options for Middle East Respiratory Syndrome Coronavirus (MERS-CoV)': 2,
#  'Treatment–donation-stockpile dynamics in ebola convalescent blood transfusion therapy': 0,
#  'Risk of transmission of airborne infection during train commute based on mathematical model': 0,
#  'Just remember this: Lexicogrammatical relevance markers in lectures': 0,
#  'Efficacy and Immunogenicity of Unmodified and Pseudouridine-Modified mRNA Delivered Systemically with Lipid Nanoparticles in Vivo': 2,
#  'Diarrhées à rotavirus et autres diarrhées virales': 0,
#  '„Emerging Infectious Diseases“: Dengue-Fieber, West-Nil-Fieber, SARS, Vogelgrippe, HIV': 0,
#  'Feasibility, safety, clinical, and laboratory effects of convalescent plasma therapy for patients with Middle East respiratory syndrome coronavirus infection: a study protocol': 2,
#  'Molecular evolution and multilocus sequence typing of 145 strains of SARS-CoV': 0,
#  'Modeling State Interventions': 0,
#  'Authoritarianism, outbreaks, and information politics': 0,
#  'In Vivo Persistence of Human Rhinoviruses in Immunosuppressed Patients': 0,
#  'Prevalence of Bartonella henselae antibodies in serum of cats with and without clinical signs of central nervous system disease': 0,
#  'New Insights from Elucidating the Role of LMP1 in Nasopharyngeal Carcinoma': 0,
#  'Persons Evaluated for 2019 Novel Coronavirus — United States, January 2020 | MMWR': 0,
#  'The vacuolar-type ATPase inhibitor archazolid increases tumor cell adhesion to endothelial cells by accumulating extracellular collagen': 0,
#  'Emergence of Novel Coronavirus 2019-nCoV: Need for Rapid Vaccine and Biologics Development': 1,
#  'Pregnancy outcome after exposure to injectable ribavirin during embryogenesis': 0,
#  'Influence of mechanical ventilation system on indoor carbon dioxide and particulate matter concentration': 2,
#  'Differential transcriptional profiles identify microglial- and macrophage-specific gene markers expressed during virus-induced neuroinflammation': 2,
#  'Highly conserved M2e and hemagglutinin epitope-based recombinant proteins induce protection against influenza virus infection': 2,
#  'Effects of genetic management on reproduction, growth, and survival in captive endangered pygmy rabbits (Brachylagus idahoensis)': 2,
#  'Do Intensive Care Data on Respiratory Infections Reflect Influenza Epidemics?': 0,
#  'VETERINARY MEDICAL ETHICS': 0,
#  'ISCCM Guidelines for the Use of Non-invasive Ventilation in Acute Respiratory Failure in Adult ICUs': 0,
#  'Dengue Fever, Hawaii, 2001–2002': 0,
#  'Study on inactivation of porcine epidemic diarrhoea virus, porcine sapelovirus 1 and adenovirus in the production and storage of laboratory spray‐dried porcine plasma': 1,
#  'Spinal cord injury, immunodepression, and antigenic challenge': 0,
#  'Function of the RNA Coliphage Qβ Proteins in Medical In Vitro Evolution': 0,
#  'Neurodegeneration as an RNA disorder': 1,
#  'Volume 30 contents and author index 2007': 0,
#  'The effects of injection of bovine vaccine into a human digit: a case report': 0,
#  'The quarantine war: the burning of the New York Marine Hospital in 1858.': 0,
#  'Chapter 9 Infections of the Gastrointestinal Tract': 0,
#  'Hantavirus RNA in Saliva from Patients with Hemorrhagic Fever with Renal Syndrome': 0,
#  'Discovery of a polyomavirus in European badgers (Meles meles) and the evolution of host range in the family Polyomaviridae': 0,
#  'Postentry Processing of Recombinant Adeno-Associated Virus Type 1 and Transduction of the Ferret Lung Are Altered by a Factor in Airway Secretions': 0,
#  'Vaccine Potential of Nipah Virus-Like Particles': 0,
#  'A host-restricted viral vector for antigen-specific immunization against Lyme disease pathogen': 0,
#  'Extensión y cuantificación de la carga inflamatoria en COVID-19 mediante tomografía computarizada': 0,
#  'Cryo-EM structures of HKU2 and SADS-CoV spike glycoproteins and insights into coronavirus evolution': 0,
#  'Clinical role of respiratory virus infection in acute otitis media Arola M.; Ruuskanen O.; Ziegler T.; Mertsola J.; Nanto-Salonen K.; Putto-Laurila A.; Viljanen M.K.; Halonen P. Pediatrics (1990) 86/6 (848–855)': 0,
#  'Site specific target binding controls RNA cleavage efficiency by the Kaposi’s sarcoma-associated herpesvirus endonuclease SOX': 2,
#  'Remote control of neural function by X-ray-induced scintillation': 2,
#  'Middle East respiratory syndrome coronavirus and bat coronavirus HKU9 both can utilize GRP78 for attachment onto host cells': 0,
#  "The Race to Zero?: China's Poaching of Taiwan's Diplomatic Allies": 0,
#  'Coinfection of diarrheagenic bacterial and viral pathogens in piglets of Northeast region of India': 0,
#  'Expression of Foot-and-Mouth Disease Virus Capsid Proteins in Silkworm-Baculovirus Expression System and Its Utilization as a Subunit Vaccine': 2,
#  'IκB kinase ɛ (IKKɛ): A therapeutic target in inflammation and cancer': 1,
#  '5580786 Dual Chamber blood culture bottle with syringe capture and piston assembly Gombrich Peter; Domanik Richard A; Mayer William Chicago, IL, United States Assigned to AccuMed Inc': 0,
#  'Sequence analysis of the leader RNA of two porcine coronaviruses: Transmissible gastroenteritis virus and porcine respiratory coronavirus': 0,
#  'Advanced Pathology Techniques for Detecting Emerging Infectious Disease Pathogens': 1,
#  'Effects of COVID 19 pandemic in daily life': 0,
#  'Infecciones virales graves en pacientes inmunocompetentes': 0,
#  'Immunogenicity of Different Forms of Middle East Respiratory Syndrome S Glycoprotein': 1,
#  '9 Zoonoses': 0,
#  'Study of Particle Dispersion on One Bed Hospital using Computational Fluid Dynamics': 0,
#  'Evaluation and Validation of an Enzyme-Linked Immunosorbent Assay and an Immunochromatographic Test for Serological Diagnosis of Severe Acute Respiratory Syndrome': 1,
#  '36 Viral Febrile Illnesses and Emerging Pathogens': 0,
#  'Virus pathogens suggest an autumn return': 0,
#  'Design, antiviral and cytostatic properties of isoxazolidine-containing amonafide analogues': 0,
#  'Viral tricks to grid-lock the type I interferon system': 0,
#  'Phylogenetic and Pathotypic Characterization of Newcastle Disease Viruses Circulating in South China and Transmission in Different Birds': 0,
#  'Under-the-radar dengue virus infections in natural populations of Aedes aegypti mosquitoes': 0,
#  'Reproduction, growth, and development of rats during chronic exposure to multiple field strengths of 60-Hz electric fields': 2,
#  'Nosocomial Contamination of Laryngoscope Handles: Challenging Current Guidelines': 0,
#  'Pentraxin 3 deficiency enhances features of chronic rejection in a mouse orthotopic lung transplantation model': 0,
#  'Establishing research priorities to improve the One Health efficacy of Australian general practitioners and veterinarians with regard to zoonoses: A modified Delphi survey': 0,
#  'Cytoplasmic Translocation of Polypyrimidine Tract-Binding Protein and Its Binding to Viral RNA during Japanese Encephalitis Virus Infection Inhibits Virus Replication': 0,
#  'Pharmacology of Chloroquine and Hydroxychloroquine': 0,
#  'Ro52 autoantibodies arise from self-reactive progenitors in a mother of a child with neonatal lupus': 2,
#  'Multiplex nested RT-PCR for the detection of porcine enteric viruses': 0,
#  'Receptor Recognition Mechanisms of Coronaviruses: a Decade of Structural Studies': 0,
#  'Marqueurs biologiques de gravité initiale des bronchiolites aiguës et d’évolution vers un asthme du nourrisson': 0,
#  'Mental Health and Psychological Intervention Amid COVID-19 Outbreak: Perspectives from South Korea': 0,
#  'Crystal structure of the serine protease domain of Sesbania mosaic virus polyprotein and mutational analysis of residues forming the S1-binding pocket': 2,
#  'Herpes Simplex Virus 1-Encoded Tegument Protein VP16 Abrogates the Production of Beta Interferon (IFN) by Inhibiting NF-κB Activation and Blocking IFN Regulatory Factor 3 To Recruit Its Coactivator CBP': 0,
#  'Type I interferon signaling facilitates the development of IL-10-producing effector CD8(+) T cells during influenza virus infection': 1,
#  'Host response to bovine viral diarrhea virus and interactions with infectious agents in the feedlot and breeding herd': 1,
#  'Fact-finding Survey of Nosocomial Infection Control in Hospitals in Kathmandu, Nepal—A Basis for Improvement': 0,
#  'Evaluation of Low versus High Volume per Minute Displacement CO(2) Methods of Euthanasia in the Induction and Duration of Panic-Associated Behavior and Physiology': 0,
#  'Estimating the germicidal effect of upper-room UVGI system on exhaled air of patients based on ventilation efficiency': 0,
#  'Functional Analysis of Mosquito-Borne Flavivirus Conserved Sequence Elements within 3′ Untranslated Region of West Nile Virus by Use of a Reporting Replicon That Differentiates between Viral Translation and RNA Replication': 0,
#  'Effect of cinnamon water extract on monocyte-to-macrophage differentiation and scavenger receptor activity': 2,
#  'Threshold parameters for a model of epidemic spread among households and workplaces': 0,
#  'An Epidemic in the Midst of a Pandemic: Opioid Use Disorder and COVID-19': 0,
#  'Sequence Heterogeneity of the ORF3 Gene of Porcine Epidemic Diarrhea Viruses Field Samples in Fujian, China, 2010–2012': 2,
#  'KAPITEL 10 Lungen- und Atemwegserkrankungen': 0,
#  'Role of Atypical Pathogens in Nursing Home–Acquired Pneumonia': 0,
#  'The intensive care unit work environment: Current challenges and recommendations for the future': 0,
#  'Long-term analysis of feline calicivirus prevalence and viral shedding patterns in naturally infected colonies of domestic cats': 0,
#  'Transmission and epidemiological characteristics of Severe Acute Respiratory Syndrome Coronavirus 2 (SARS-CoV-2) infected Pneumonia (COVID-19): preliminary evidence obtained in comparison with 2003-SARS': 0,
#  'Intracellular Events and Cell Fate in Filovirus Infection': 0,
#  'Comparative safety of vaccine adjuvants: a summary of current evidence and future needs': 0,
#  'The protective role of microRNA-21 against coxsackievirus B3 infection through targeting the MAP2K3/P38 MAPK signaling pathway': 0,
#  'Clinical features of 2019 novel coronavirus infection patients and a feasible screening procedure': 0,
#  'Cryo X-ray nano-tomography of vaccinia virus infected cells': 2,
#  'KAPITEL 33 Wichtige arbeitsmedizinische und hygienische Risiken': 0,
#  'Neonatal Foal Diarrhea': 0,
#  'Personal sampler for monitoring of viable viruses; modelling of outdoor sampling conditions': 0,
#  'Chapter 54 Immunopathogenesis of Asthma': 0,
#  'Should, and how can, exercise be done during a coronavirus outbreak? — An interview with Dr. Jeffrey A. Woods': 0,
#  'Detailed Mechanistic Insights into HIV-1 Sensitivity to Three Generations of Fusion Inhibitors': 0,
#  'Bench-to-bedside review: Adjuncts to mechanical ventilation in patients with acute lung injury': 0,
#  'The GenMark ePlex(®): another weapon in the syndromic arsenal for infection diagnosis': 0,
#  'Synthesis and antiviral evaluation of acyclic azanucleosides developed from sulfanilamide as a lead structure': 2,
#  'Health assembly adopts new regulations for tackling emergencies': 0,
#  'Chapter 20 Vaccines the tugboat for prevention-based animal production': 0,
#  'Chapter 25 Electrofusion Nuclear Reprogramming of Somatic Cells by Cell Hybridization with Pluripotential Stem Cells': 0,
#  'Differential Cell Count and CRP Level in Blood as Predictors for Middle East Respiratory Syndrome Coronavirus Infection in Acute Febrile Patients during Nosocomial Outbreak': 2,
#  'ELL Protein-associated Factor 2 (EAF2) Inhibits Transforming Growth Factor β Signaling through a Direct Interaction with Smad3': 0,
#  'Use of Obstetric Practice Web Sites to Distribute Zika Virus Information to Pregnant Women During a Zika Virus Outbreak': 0,
#  'Effect van influenzavaccinatie op het aantal sterfgevallen tijdens perioden van verhoogde circulatie van influenzavirus in de populatie': 0,
#  'Recombinant Newcastle Disease Virus as a Vaccine Vector for Cancer Therapy': 0,
#  'Patterns of perception toward influenza pandemic among the front-line responsible health personnel in southern Thailand: a Q methodology approach': 0,
#  'Pulmonary penetration of piperacillin and tazobactam in critically ill patients': 0,
#  'Primary demyelination in transgenic mice expressing interferon-γ': 2,
#  'Innate immune response and bronchiolitis and preschool recurrent wheeze': 0,
#  'Anti-hepatitis C virus potency of a new autophagy inhibitor using human liver slices model': 0,
#  'Review of Literature for Air Medical Evacuation High-Level Containment Transport': 0,
#  'SDRA par pneumonie à EBV': 0,
#  'From SARS to H7N9: will history repeat itself?': 0,
#  'Cyclophilin A up-regulates MMP-9 expression and adhesion of monocytes/macrophages via CD147 signalling pathway in rheumatoid arthritis': 2,
#  'Infectious diseases of the respiratory system': 0,
#  'Molecular characterization and phylogenetic analysis of transmissible gastroenteritis virus HX strain isolated from China': 2,
#  'Enhanced growth of influenza A virus by coinfection with human parainfluenza virus type 2': 2,
#  'Nanobioimaging and sensing of infectious diseases': 1,
#  'Digital archive of Lancet is launched': 0,
#  'Togaviridae': 0,
#  'A resequencing pathogen microarray method for high-throughput molecular diagnosis of multiple etiologies associated with central nervous system infection': 0,
#  'Asthma in Pregnancy: Pathophysiology, Diagnosis, Whole-Course Management, and Medication Safety': 0,
#  'Risk estimation of infectious diseases determines the effectiveness of the control strategy': 2,
#  'Environmental effects on parasitic disease transmission exemplified by schistosomiasis in western China': 2,
#  'The three domains of public health: An internationally relevant basis for public health education?': 0,
#  'COVID-19 Checklist: Mask, Gloves, and Video Chatting with Grandpa': 0,
#  'DExD/H-Box Helicase 36 Signaling via Myeloid Differentiation Primary Response Gene 88 Contributes to NF-κB Activation to Type 2 Porcine Reproductive and Respiratory Syndrome Virus Infection': 0,
#  'Intestinal changes associated with rotavirus and enterotoxigenic Escherichia coli infection in calves': 0,
#  'Society, Differentiation and Globalisation': 0,
#  'Human rights and other provisions in the revised International Health Regulations (2005)': 0,
#  'Rapid characterization of microorganisms by mass spectrometry - What can be learned and how?': 0,
#  'Editorial: Emerging Viruses: Host Immunity and Novel Therapeutic Interventions': 2,
#  'Encouraging rational antibiotic use in childhood pneumonia: a focus on Vietnam and the Western Pacific Region': 0,
#  'Clinical trial analysis of 2019-nCoV therapy registered in China': 2,
#  'Marburg Virus Angola Infection of Rhesus Macaques: Pathogenesis and Treatment with Recombinant Nematode Anticoagulant Protein c2': 1,
#  'Modulation of metabolic functions through Cas13d-mediated gene knockdown in liver': 2,
#  'Triggering ubiquitination of IFNAR1 protects tissues from inflammatory injury': 0,
#  'Multiplex real time PCRs for detection of influenza A subtypes including H5N1': 0,
#  'History of respiratory medicine in Canada: A new Canadian Respiratory Journal series': 0,
#  'Health Technology Assessment of pathogen reduction technologies applied to plasma for clinical use': 0,
#  'Multi-Clade H5N1 Virus-Like Particles: Immunogenicity and Protection against H5N1 Virus and Effects of Beta-Propiolactone': 0,
#  'PARENTAL ORIGIN OF CHROMOSOME 15 DELETION IN PRADER-WILLI SYNDROME': 0,
#  'Conserved presence of G-quadruplex forming sequences in the Long Terminal Repeat Promoter of Lentiviruses': 0,
#  'Mechanisms and impact of the frequent exacerbator phenotype in chronic obstructive pulmonary disease': 0,
#  'Highly diversified shrew hepatitis B viruses corroborate ancient origins and divergent infection patterns of mammalian hepadnaviruses': 0,
#  'Tandem leader proteases of Grapevine leafroll-associated virus-2: Host-specific functions in the infection cycle': 0,
#  'Caveolin-1 and -2 in airway epithelium: expression and in situ association as detected by FRET-CLSM': 0,
#  'KCDC Risk Assessments on the Initial Phase of the COVID-19 Outbreak in Korea': 0,
#  'Probability of introducing porcine epidemic diarrhea virus into Danish pig herds by imported spray-dried porcine plasma': 0,
#  'Declining Influenza Vaccination Coverage among Nurses, Hong Kong, 2006–2012': 0,
#  'A methodology for optimal placement of sensors in enclosed environments: A dynamical systems approach': 0,
#  'Functional analysis of the receptor binding domain of SARS coronavirus S1 region and its monoclonal antibody': 0,
#  'The Fight against the 2019-nCoV Outbreak: an Arduous March Has Just Begun': 0,
#  'Sialic Acid Binding Activity of Transmissible Gastroenteritis Coronavirus Affects Sedimentation Behavior of Virions and Solubilized Glycoproteins': 2,
#  'In vivo morphogenesis of a new porcine enteric coronavirus, CV 777': 0,
#  'Secondary Household Transmission of SARS, Singapore': 0,
#  'Positional clustering improves computational binding site detection and identifies novel cis-regulatory sites in mammalian GABA(A) receptor subunit genes': 2,
#  'Blood Screening for Influenza': 0,
#  'The Ethanol Extract from Lonicera japonica Thunb. Regresses Nonalcoholic Steatohepatitis in a Methionine- and Choline-Deficient Diet-Fed Animal Model': 2,
#  'Transcriptional profiles of PBMCs from pigs infected with three genetically diverse porcine reproductive and respiratory syndrome virus strains': 0,
#  'The use of a multiplex real-time PCR assay for diagnosing acute respiratory viral infections in children attending an emergency unit': 2,
# ...
#  'From SARS to COVID-19: A previously unknown SARS- related coronavirus (SARS-CoV-2) of pandemic potential infecting humans – Call for a One Health approach': 0,
#  'Identification of an aprotinin antiviral domain': 0,
#  'The Antiviral Effector IFITM3 Disrupts Intracellular Cholesterol Homeostasis to Block Viral Entry': 0,
#  'Transmission Dynamics and Prospective Environmental Sampling of Adenovirus in a Military Recruit Setting': 0,
#  'Characterization of Human Coronavirus Etiology in Chinese Adults with Acute Upper Respiratory Tract Infection by Real-Time RT-PCR Assays': 0,
#  'Chapter 10 Plant-Based Peroral Vaccines': 0,
#  'Nasal swab samples and real-time polymerase chain reaction assays in community-based, longitudinal studies of respiratory viruses: the importance of sample integrity and quality control': 0,
#  'Chapter 4 Myelination, Dysmyelination, and Demyelination': 0,
#  'Distribution of antibodies against influenza virus in pigs from farrow-to-finish farms in Minas Gerais state, Brazil': 1,
#  'Middle East Respiratory Syndrome Coronavirus, Saudi Arabia, 2017–2018': 0,
#  'Stimulation of interferon and cytokine gene expression by imiquimod and stimulation by Sendai virus utilize similar signal transduction pathways.': 0,
#  'Assessing Ebola-related web search behaviour: insights and implications from an analytical study of Google Trends-based query volumes': 0,
#  'Contents of volume 22': 0,
#  'Future Perspectives on Infections Associated with Gastrointestinal Tract Diseases': 0,
#  'Regulated and Liver-Specific Tamarin Alpha Interferon Gene Delivery by a Helper-Dependent Adenoviral Vector': 0,
#  'Diagnosis of enteritis virus.': 0,
#  'High level expression of surface glycoprotein of rabies virus in tobacco leaves and its immunoprotective activity in mice': 2,
#  'Uncoupling RNA virus replication from transcription via the polymerase: functional and evolutionary insights': 0,
#  'Differentially expressed non-coding RNAs induced by transmissible gastroenteritis virus potentially regulate inflammation and NF-κB pathway in porcine intestinal epithelial cell line': 2,
#  'Porcine Intestinal Enteroids: a New Model for Studying Enteric Coronavirus Porcine Epidemic Diarrhea Virus Infection and the Host Innate Response': 0,
#  'Mobility and Interactions of Coronavirus Nonstructural Protein 4': 0,
#  'Progress towards Health for All: Time to End Discrimination and Marginalization': 0,
#  'Proceedings 26th Symposium ESVN‐ECVN': 0,
#  'Exploring motivations behind pollution-mask use in a sample of young adults in urban China': 0,
#  'Planning horizon affects prophylactic decision-making and epidemic dynamics': 2,
#  'Molecular Signatures of Obstructive Sleep Apnea in Adults: A Review and Perspective': 2,
#  'Pathogenic viruses: Molecular detection and characterization': 1,
#  'A Single Amino Acid Change in the Hemagglutinin Protein of Measles Virus Determines Its Ability To Bind CD46 and Reveals Another Receptor on Marmoset B Cells': 0,
#  'Monitoring the COVID-19 epidemic in the context of widespread local transmission': 0,
#  'Inducible Interleukin 32 (IL-32) Exerts Extensive Antiviral Function via Selective Stimulation of Interferon λ1 (IFN-λ1)': 2,
#  'Pathogenic role of HMGB1 in SARS?': 0,
#  'Can we measure ‘Sensationalisim’ and ‘Spin’?': 0,
#  '4.06 Safe Sanitation in Low Economic Development Areas': 0,
#  'Occurrence of viruses in human stools in the Ahaggar (Alberia).': 0,
#  'Chapter 39 General Considerations Concerning Safety in Biomedical Research Laboratories': 0,
#  'Inhibition of avian leukosis virus subgroup J replication by miRNA targeted against env': 1,
#  'Oxidation of Membrane Curvature-Regulating Phosphatidylethanolamine Lipid Results in Formation of Bilayer and Cubic Structures': 0,
#  'Next-Generation Sequencing in Veterinary Medicine: How Can the Massive Amount of Information Arising from High-Throughput Technologies Improve Diagnosis, Control, and Management of Infectious Diseases?': 0,
#  'Production, purification, and evaluation of quail immunoglobulin Y against Salmonella typhimurium and Salmonella enteritidis': 2,
#  'Structural insights into ubiquitin recognition and Ufd1 interaction of Npl4': 0,
#  'Acute disseminated encephalomyelitis: a call to the clinicians for keeping this rare condition on clinical radar': 0,
#  'Soluble Receptor-Mediated Targeting of Mouse Hepatitis Coronavirus to the Human Epidermal Growth Factor Receptor': 0,
#  'Cell replacement therapies to promote remyelination in a viral model of demyelination': 1,
#  'The human Transmembrane Protease Serine 2 is necessary for the production of Group 2 influenza A virus pseudotypes': 0,
#  'Novel coronavirus pneumonia in the primary general hospital of treatment based on traditional Chinese medicine syndrome differentiation and prevention': 0,
#  'Health in times of uncertainty in the eastern Mediterranean region, 1990–2013: a systematic analysis for the Global Burden of Disease Study 2013': 0,
#  'Selective Degradation of Host RNA Polymerase II Transcripts by Influenza A Virus PA-X Host Shutoff Protein': 1,
#  'Chapter 26 Zoonoses and Other Human Health Hazards': 0,
#  'The Individual and Population Genetics of Antibody Immunity': 1,
#  'The psychological impact of the COVID-19 epidemic on college students in China': 0,
#  'Síndrome de distrés respiratorio agudo. Conclusiones y perspectivas de futuro': 0,
#  'Intravenous sufentanil-midazolam versus sevoflurane anaesthesia in medetomidine pre-medicated Himalayan rabbits undergoing ovariohysterectomy': 2,
#  'Conocimientos básicos sobre enfermedades víricas emergentes: apuntes para atención primaria (parte 1)': 0,
#  'Etablierung eines fischvirus empfänglichen zellstammes aus Hypophysen des Karpfens (Cyprinus carpio L.)': 0,
#  'Effectiveness of a novel immunogenic nanoparticle platform for Toxoplasma peptide vaccine in HLA transgenic mice': 2,
#  'Hepatitis B Virus Protein X-induced Expression of the CXC Chemokine IP-10 Is Mediated through Activation of NF-κB and Increases Migration of Leukocytes': 1,
#  'SARS, Cough, and Fever—or Is It SARS, Fever, and Cough?': 0,
#  'Label-free microcantilever-based immunosensors for highly sensitive determination of avian influenza virus H9': 2,
#  'Serotypes of bovine astrovirus.': 0,
#  'Sustaining Hospital Readiness for Ebola': 0,
#  'Validation of assays to monitor immune responses in the Syrian golden hamster (Mesocricetus auratus)': 1,
#  'Heme Oxygenase-1-Expressing Dendritic Cells Promote Foxp3(+) Regulatory T Cell Differentiation and Induce Less Severe Airway Inflammation in Murine Models': 2,
#  'Electron microscopy of the intestine of gnotobiotic piglets infected with porcine rotavirus': 0,
#  'A functional different immune capacity in cattle is associated with higher mastitis incidence': 0,
#  'Identification and characterisation of the CD40-ligand of Sigmodon hispidus': 0,
#  'Glycyrrhizin, an active component of liquorice roots, and replication of SARS-associated coronavirus': 2,
#  'Acyclic nucleoside phosphonates containing the amide bond: hydroxy derivatives': 0,
#  'Considerations for the design of vaccine efficacy trials during public health emergencies': 1,
#  'The p23 Protein of Citrus Tristeza Virus Controls Asymmetrical RNA Accumulation': 0,
#  'The Active Role of a Blood Center in Outpacing the Transfusion Transmission of COVID-19': 0,
#  'Genome-Wide Transcriptional Profiling Reveals Two Distinct Outcomes in Central Nervous System Infections of Rabies Virus': 2,
#  'The structural basis of paramyxovirus invasion': 0,
#  'Cervical: Lymphadenopathy': 0,
#  'Infiltrating Cells and IFNγ Production in the Injected Eye After Uniocular Anterior Chamber Inoculation of HSV-1': 0,
#  'Bioanalysis of eukaryotic organelles': 0,
#  'Seasonal Influenza Forecasting in Real Time Using the Incidence Decay With Exponential Adjustment Model': 0,
#  'Immunization with Modified Vaccinia Virus Ankara-Based Recombinant Vaccine against Severe Acute Respiratory Syndrome Is Associated with Enhanced Hepatitis in Ferrets': 1,
#  '99mTc-radiolabeled Levofloxacin and micelles as infection and inflammation imaging agents': 2,
#  'Immuno-modulating properties of Tulathromycin in porcine monocyte-derived macrophages infected with porcine reproductive and respiratory syndrome virus': 1,
#  "Sources of Type I Interferons in Infectious Immunity: Plasmacytoid Dendritic Cells Not Always in the Driver's Seat": 2,
#  'Toward a conceptualization of supplier-switching processes in business relationships': 0,
#  'Viral load and outcome in SARS infection: The role of personal protective equipment in the emergency department': 0,
#  'Modelling the epidemic trend of the 2019 novel coronavirus outbreak in China': 1,
#  'Mass Gatherings and Respiratory Disease Outbreaks in the United States – Should We Be Worried? Results from a Systematic Literature Review and Analysis of the National Outbreak Reporting System': 0,
#  'Analysis of effects of tRNA:message stability on frameshift frequency at the Escherichia coli RF2 programmed frameshift site.': 0,
#  'Development of real-time recombinase polymerase amplification assay for rapid and sensitive detection of canine parvovirus 2': 0,
#  'Respiratory viral coinfection and disease severity in children: A systematic review and meta-analysis': 0,
#  'Coronavirus in China': 0,
#  'Nelfinavir was predicted to be a potential inhibitor of 2019-nCov main protease by an integrative approach combining homology modelling, molecular docking and binding free energy calculation': 2,
#  'Genetically engineered vaccines for mycobacterial antigens comprising recombinant poxvirus, e.g. vaccinia virus, capable of expressing Mycobacterium leprae, Mycobacterium tuberculosis or Mycobacterium bovis antigens': 0,
#  'Characterization of a Novel Betacoronavirus Related to Middle East Respiratory Syndrome Coronavirus in European Hedgehogs': 0,
#  'Quantitative Delineation of Herpesviruses in Bats for use in Ecological Studies': 2,
#  'Treating the Immunocompetent Patient Who Presents with an Upper Respiratory Infection: Pharyngitis, Sinusitis, and Bronchitis': 0,
#  'Control of antibiotic-resistant bacteria in the office and clinic': 0,
#  'Rapid drop in the reproduction number during the Ebola outbreak in the Democratic Republic of Congo': 0,
#  'Mild acute inflammatory stimulation induces transient negative mood': 0,
#  'DCGR: feature extractions from protein sequences based on CGR via remodeling multiple information': 2,
#  'Widespread use of face masks in public may slow the spread of SARS CoV-2: an ecological study': 0,
#  'Rhinopharyngite aiguë': 0,
#  'Pathogenic Leptospira spp. in bats: Molecular investigation in Southern Brazil': 0,
#  'Immunoreceptors on neutrophils': 2,
#  'Absence of Middle East respiratory syndrome coronavirus in Bactrian camels in the West Inner Mongolia Autonomous Region of China: surveillance study results from July 2015': 1,
#  'The Activity of Influenza and Influenza-like Viruses in Individuals Aged over 14 in the 2015/2016 Influenza Season in Poland': 0,
#  'Virus shedding patterns in nasopharyngeal and fecal specimens of COVID-19 patients': 0,
#  'Virus-induced secondary bacterial infection: a concise review': 0,
#  'H5N1 influenza viruses: Facts, not fear': 0,
#  'Detection and Characterization of Bovine Coronaviruses in Fecal Specimens of Adult Cattle with Diarrhea during the Warmer Seasons': 0,
#  'Re-understanding anti-influenza strategy: attach equal importance to antiviral and anti-inflammatory therapies': 2,
#  'Disease Spreading in Time-Evolving Networked Communities': 0,
#  'Frameshifting RNA pseudoknots: Structure and mechanism': 0,
#  'Severe respiratory illness associated with a nationwide outbreak of enterovirus D68 in the USA (2014): a descriptive epidemiological investigation': 0,
#  'Absolute Humidity Influences the Seasonal Persistence and Infectivity of Human Norovirus': 0,
#  'Environmental Contamination and Viral Shedding in MERS Patients During MERS-CoV Outbreak in South Korea': 0,
#  'Prevalence of human parainfluenza virus in patients with acute respiratory tract infections in Beijing, 2011–2014': 0,
#  'Volume contents and index to volume 1': 0,
#  'Variable evolutionary routes to host establishment across repeated rabies virus host shifts among bats': 0,
#  'Anti-inflammatory properties of Type I interferons': 1,
#  'Low expression of dendritic cell-specific intercellular adhesion molecule-grabbing nonintegrin-related protein in lung cancer and significant correlations with brain metastasis and natural killer cells': 2,
#  'A Novel Sample Processing Method for Rapid Detection of Tuberculosis in the Stool of Pediatric Patients Using the Xpert MTB/RIF Assay': 2,
#  'Review: Micronutrient Selenium Deficiency Influences Evolution of Some Viral Infectious Diseases': 0,
#  'Immunological Aspects of Systemic Vasculitis': 0,
#  'Chapter 57 Infections Associated with Retinal Autoimmunity': 1,
#  'CME Tropical Medicine (123847): self-assessment questionnaire': 0,
#  'Investigation of Antibody-Dependent Enhancement (ADE) of SARS coronavirus infection and its role in pathogenesis of SARS': 2,
#  'Investigations into the presence of nidoviruses in pythons': 0,
#  'The biomechanical role of extra-axonemal structures in shaping the flagellar beat of Euglena': 0,
#  'In vivo study of interferon-alpha-secreting cells in pig foetal lymphohaematopoietic organs following in utero TGEV coronavirus injection': 0,
#  'The potential of recurrent epidemics and pandemics in a highly mobile global society': 0,
#  'Detection of Air and Surface Contamination by Severe Acute Respiratory Syndrome Coronavirus 2 (SARS-CoV-2) in Hospital Rooms of Infected Patients': 0,
#  'Suppressive effect of dengue virus envelope protein domain III on megakaryopoiesis': 0,
#  'Author index (volume 5)': 0,
#  'Effects of 3 Rodent Beddings on Biochemical Measures in Rats and Mice': 0,
#  'Towards a small animal model for hepatitis C': 0,
#  'Extracorporeal shockwave therapy in osteonecrosis of femoral head: A systematic review of now available clinical evidences': 2,
#  'Acceptability of A/H1N1 vaccination during pandemic phase of influenza A/H1N1 in Hong Kong: population based cross sectional survey': 1,
#  'Translation in plants-rules and exceptions': 0,
#  'In Utero Infection by Porcine Reproductive and Respiratory Syndrome Virus Is Sufficient To Increase Susceptibility of Piglets to Challenge by Streptococcus suis Type II': 0,
#  'Historical linkages: epidemic threat, economic risk, and xenophobia': 0,
#  'Using the Incidence Decay and Exponential Adjustment (IDEA) model to understand transmission dynamics of MERS-CoV in a camel herd': 0,
#  'Generation of Functional Blocking Monoclonal Antibodies Against Mouse Interleukin-12 p40 Homodimer and Monomer': 0,
#  'Lack of Secondary Transmission of Ebola Virus from Healthcare Worker to 238 Contacts, United Kingdom, December 2014': 0,
#  'Health protection guideline of passenger transport stations and transportation facilities during novel coronavirus pneumonia (NCP) outbreak': 0,
#  'DNA vaccine encoding Middle East respiratory syndrome coronavirus S1 protein induces protective immune responses in mice': 1,
#  'Isolation and characterization of an astrovirus causing fatal visceral gout in domestic goslings': 0,
#  '2019 Novel coronavirus: where we are and what we know': 0,
#  'SARS in the intensive care unit': 0,
#  'Characterization of the Interaction between Human Respiratory Syncytial Virus and the Cell Cycle in Continuous Cell Culture and Primary Human Airway Epithelial Cells': 0,
#  'Tropheryma whipplei in Children with Gastroenteritis': 0,
#  'Emerging respiratory agents: New viruses for old diseases?': 0,
#  'Epimeric methylsulfinyladenosine derivatives from the marine ascidian Herdmania momus': 0,
#  'Expansion of polyreactive B cells cross-reactive to HLA and self in the blood of a patient with kidney graft rejection': 1,
#  'Phlorotannins': 2,
#  'Fasciola hepatica glycoconjugates immuneregulate dendritic cells through the Dendritic Cell-Specific Intercellular adhesion molecule-3-Grabbing Non-integrin inducing T cell anergy': 1,
#  ...}

# %%
class ScoreEnsemble:
  def __init__(self):
    self.df = None
    self.weights = None
    self.scores = None
    self.combined_scores = None
    self.sorted_vaccine_titles = None
    self.sorted_theurap_titles = None
    self.root_path = '' ## need specify root_path

  def _load_metadata_df(self, df_path): ## need specify df_path
    if self.df:
      return self.df
    
    self.df = pd.read_csv(f'{self.root_path}/df_path')
    return self.df

  def _load_scores_from_json(self):
    """ Load scores that are stored in json files """
    if self.scores:
      return self.scores

    file_names = ['1.json', '2.json', '3.json', '4.json', '5.json']
    scores = []
    for file_name in file_names:
      scores.append(json.load(f'{self.root_path}/file_name'))
    self.scores = scores
    return self.scores

  def _train_weights(self): # need implementation if want to train weights
    if self.weights:
      return self.weights

    self.weight = [1] * 5
    return self.weights

  def _aggregate_scores(self):
    if self.combined_scores:
      return self.combined_scores

    weights = self._train_weights()
    scores = self._load_scores_from_json()
    # get all keys/titles
    all_titles = set()
    for score in self.scores:
      all_titles |= set(score.keys())
    # combine scores
    combined_scores = defaultdict(float)
    for title in titles:
      for weight, score in zip(weights, scores):
        score4title = score.get(title)
        score4title = np.asarray(score4title) if score4title else np.asarray((1/3, 1/3, 1/3))
        combined_scores[title] += weight * score4title
    self.combined_scores =  combined_scores
    return self.combined_scores
    
  def _sort_by_score(self):
    if self.sorted_vaccine_titles and self.sorted_theurap_titles:
      return self.sorted_vaccine_titles, self.sorted_theurap_titles
      
    combined_scores = _aggregate_scores()
    self.sorted_vaccine_titles = [k for k, v in sorted(combined_scores.items(), reverse=True, key=lambda item: item[1][0])]
    self.sorted_theurap_titles = [k for k, v in sorted(combined_scores.items(), reverse=True, key=lambda item: item[1][1])]
    return self.sorted_vaccine_titles, self.sorted_theurap_titles
  
  def get_top_K(self, cls='vaccine', K=100):
    sorted_vaccine_titles, sorted_theurap_titles = _sort_by_score()
    if cls == 'vaccine':
      top_k_titles = set(sorted_vaccine_titles[:K])
    elif cls == 'therap' or cls == 'therapeutics':
      top_k_titles = set(sorted_theurap_titles[:K])
    else:
      raise NotImplementedError(f'Not type call \"{cls}\", please set cls to \"vaccine\" or \"therap\"')

    df = self._load_metadata_df()
    return df.loc[df['title'].isin(top_k_titles)]

  def get_score_given_title(self, title):
    combined_scores = _aggregate_scores()
    score = combined_scores[title]
    print(f'vaccines: {score[0]}, therapeutics: {score[1]}, other: {score[2]}')
    return score
